# %% [markdown]
# # Group Assignment
# ## Covid-19 Data - ETL Process
# **Group Participants:**
# - Uxía Lojo
# - Emiliano Puertas
# - María Camila Sanabria
# - Joshua Vanderspuy
# - Sebastian Zambrano

# %% [markdown]
# ### **Part I: Extracting Process**
# In this first part, we will create a function to extract the information from each table and converting them into data frames that we can use.
# For this, we will take into account:
# 1. You have to build a big table containing all info from the original CSV files.
#
# We assume we will always be receiving all 6 files.

# %%
import pandas as pd
import os

# %%
# We create the data extraction function
def data_extraction(directory):

    # We create a dictionary that will contain our tables in order to make our job easier later.
    tables={} 
    
    #We extract only the list of FILES, without folders.
    
    files=[file for file in os.listdir(directory) if os.path.isfile(os.path.join(directory,file))]
    
    # We need to create a for loop to go through the files in our path and save them as a data frame in our directory
    for file in files:
        #We store the DataFrames in our table.
        tables[file]=pd.read_csv(os.path.join(directory,file))
    
    return tables

# %% [markdown]
# Using the function with our current directory and data sets

# %%
data=data_extraction("data/")

# %%
data
# Out:
# {'demographics':      location_key  population  population_male  population_female  \
#  0     DE_BB_12051     72124.0          35617.0            36507.0
#  1     DE_BB_12052    100219.0          49201.0            51018.0
#  2     DE_BB_12053     57873.0          28023.0            29850.0
#  3     DE_BB_12054    178089.0          86179.0            91910.0
#  4     DE_BB_12060    182760.0          90615.0            92145.0
#  ...           ...         ...              ...                ...
#  5092  US_WY_56037     43464.0          22438.0            21026.0
#  5093  US_WY_56039     23384.0          12133.0            11251.0
#  5094  US_WY_56041     20431.0          10339.0            10092.0
#  5095  US_WY_56043      8010.0           4055.0             3955.0
#  5096  US_WY_56045      6968.0           3660.0             3308.0
#
#        population_rural  population_urban  population_largest_city  \
#  0                  NaN               NaN                      NaN
#  1                  NaN               NaN                      NaN
#  2                  NaN               NaN                      NaN
#  3                  NaN               NaN                      NaN
#  4                  NaN               NaN                      NaN
#  ...                ...               ...                      ...
#  5092               NaN               NaN                      NaN
#  5093               NaN               NaN                      NaN
#  5094               NaN               NaN                      NaN
#  5095               NaN               NaN                      NaN
#  5096               NaN               NaN                      NaN
#
#        population_clustered  population_density  human_development_index  \
#  0                      NaN               367.4                      NaN
#  1                      NaN               609.9                      NaN
#  2                      NaN               403.2                      NaN
#  3                      NaN              1034.5                      NaN
#  4                      NaN               126.8                      NaN
#  ...                    ...                 ...                      ...
#  5092                   NaN                 NaN                      NaN
#  5093                   NaN                 NaN                      NaN
#  5094                   NaN                 NaN                      NaN
#  5095                   NaN                 NaN                      NaN
#  5096                   NaN                 NaN                      NaN
#
#        population_age_00_09  population_age_10_19  population_age_20_29  \
#  0                   6029.0                5183.0                6646.0
#  1                   8542.0                7657.0               10979.0
#  2                   4652.0                4702.0                5977.0
#  3                  18893.0               15636.0               21671.0
#  4                  16693.0               15671.0               12966.0
#  ...                    ...                   ...                   ...
#  5092                6334.0                6333.0                5488.0
#  5093                2461.0                2245.0                3184.0
#  5094                3282.0                3182.0                2179.0
#  5095                 913.0                1162.0                 705.0
#  5096                 777.0                 789.0                 728.0
#
#        population_age_30_39  population_age_40_49  population_age_50_59  \
#  0                   9776.0                7690.0               11604.0
#  1                  13671.0               10652.0               15833.0
#  2                   7066.0                6405.0                9325.0
#  3                  28980.0               23226.0               24768.0
#  4                  23038.0               22973.0               33665.0
#  ...                    ...                   ...                   ...
#  5092                6734.0                5219.0                5534.0
#  5093                4184.0                3404.0                2968.0
#  5094                2755.0                2349.0                2567.0
#  5095                 938.0                 902.0                1101.0
#  5096                 932.0                 741.0                1009.0
#
#        population_age_60_69  population_age_70_79  population_age_80_and_older
#  0                  10152.0                8681.0                       6363.0
#  1                  14258.0               10758.0                       7869.0
#  2                   9042.0                6049.0                       4655.0
#  3                  18998.0               14762.0                      11155.0
#  4                  27041.0               18553.0                      12160.0
#  ...                    ...                   ...                          ...
#  5092                4815.0                2063.0                        944.0
#  5093                2855.0                1435.0                        648.0
#  5094                2496.0                1116.0                        505.0
#  5095                1106.0                 752.0                        431.0
#  5096                1068.0                 541.0                        383.0
#
#  [5097 rows x 19 columns],
#  'epidemiology':                date location_key  new_confirmed  new_deceased  new_recovered  \
#  0        2020-03-15  DE_BB_12051            2.0           0.0            2.0
#  1        2020-03-17  DE_BB_12051            1.0           0.0            1.0
#  2        2020-03-19  DE_BB_12051            2.0           0.0            2.0
#  3        2020-03-20  DE_BB_12051            1.0           0.0            1.0
#  4        2020-03-22  DE_BB_12051            2.0           0.0            2.0
#  ...             ...          ...            ...           ...            ...
#  3161028  2022-05-09  US_WY_56045            0.0           0.0            NaN
#  3161029  2022-05-10  US_WY_56045           -1.0           0.0            NaN
#  3161030  2022-05-11  US_WY_56045            0.0           0.0            NaN
#  3161031  2022-05-12  US_WY_56045            0.0           0.0            NaN
#  3161032  2022-05-13  US_WY_56045            0.0           0.0            NaN
#
#           new_tested  cumulative_confirmed  cumulative_deceased  \
#  0               NaN                   2.0                  0.0
#  1               NaN                   3.0                  0.0
#  2               NaN                   5.0                  0.0
#  3               NaN                   6.0                  0.0
#  4               NaN                   8.0                  0.0
#  ...             ...                   ...                  ...
#  3161028         NaN                1589.0                 18.0
#  3161029         NaN                1588.0                 18.0
#  3161030         NaN                1588.0                 18.0
#  3161031         NaN                1588.0                 18.0
#  3161032         NaN                1588.0                 18.0
#
#           cumulative_recovered  cumulative_tested
#  0                         2.0                NaN
#  1                         3.0                NaN
#  2                         5.0                NaN
#  3                         6.0                NaN
#  4                         8.0                NaN
#  ...                       ...                ...
#  3161028                   NaN                NaN
#  3161029                   NaN                NaN
#  3161030                   NaN                NaN
#  3161031                   NaN                NaN
#  3161032                   NaN                NaN
#
#  [3161033 rows x 10 columns],
#  'health':      location_key  life_expectancy  smoking_prevalence  diabetes_prevalence  \
#  0     US_AK_02013        86.900000                 NaN                  NaN
#  1     US_AK_02016        77.750000                 NaN                  NaN
#  2     US_AK_02020        78.034694                 NaN                  NaN
#  3     US_AK_02050        78.733333                 NaN                  NaN
#  4     US_AK_02060        79.900000                 NaN                  NaN
#  ...           ...              ...                 ...                  ...
#  3017  US_WY_56037        79.177778                 NaN                  NaN
#  3018  US_WY_56039        81.950000                 NaN                  NaN
#  3019  US_WY_56041        77.700000                 NaN                  NaN
#  3020  US_WY_56043        80.600000                 NaN                  NaN
#  3021  US_WY_56045        78.800000                 NaN                  NaN
#
#        infant_mortality_rate  adult_male_mortality_rate  \
#  0                       NaN                        NaN
#  1                       NaN                        NaN
#  2                       NaN                        NaN
#  3                       NaN                        NaN
#  4                       NaN                        NaN
#  ...                     ...                        ...
#  3017                    NaN                        NaN
#  3018                    NaN                        NaN
#  3019                    NaN                        NaN
#  3020                    NaN                        NaN
#  3021                    NaN                        NaN
#
#        adult_female_mortality_rate  pollution_mortality_rate  \
#  0                             NaN                       NaN
#  1                             NaN                       NaN
#  2                             NaN                       NaN
#  3                             NaN                       NaN
#  4                             NaN                       NaN
#  ...                           ...                       ...
#  3017                          NaN                       NaN
#  3018                          NaN                       NaN
#  3019                          NaN                       NaN
#  3020                          NaN                       NaN
#  3021                          NaN                       NaN
#
#        comorbidity_mortality_rate  hospital_beds_per_1000  nurses_per_1000  \
#  0                            NaN                     NaN              NaN
#  1                            NaN                     NaN              NaN
#  2                            NaN                     NaN              NaN
#  3                            NaN                     NaN              NaN
#  4                            NaN                     NaN              NaN
#  ...                          ...                     ...              ...
#  3017                         NaN                     NaN              NaN
#  3018                         NaN                     NaN              NaN
#  3019                         NaN                     NaN              NaN
#  3020                         NaN                     NaN              NaN
#  3021                         NaN                     NaN              NaN
#
#        physicians_per_1000  health_expenditure_usd  \
#  0                     NaN                     NaN
#  1                     NaN                     NaN
#  2                     NaN                     NaN
#  3                     NaN                     NaN
#  4                     NaN                     NaN
#  ...                   ...                     ...
#  3017                  NaN                     NaN
#  3018                  NaN                     NaN
#  3019                  NaN                     NaN
#  3020                  NaN                     NaN
#  3021                  NaN                     NaN
#
#        out_of_pocket_health_expenditure_usd
#  0                                      NaN
#  1                                      NaN
#  2                                      NaN
#  3                                      NaN
#  4                                      NaN
#  ...                                    ...
#  3017                                   NaN
#  3018                                   NaN
#  3019                                   NaN
#  3020                                   NaN
#  3021                                   NaN
#
#  [3022 rows x 14 columns],
#  'hospitalizations':             date location_key  new_hospitalized_patients  \
#  0     2020-03-23    US_CA_SFO                        NaN
#  1     2020-03-24    US_CA_SFO                        NaN
#  2     2020-03-25    US_CA_SFO                        NaN
#  3     2020-03-26    US_CA_SFO                        NaN
#  4     2020-03-27    US_CA_SFO                        NaN
#  ...          ...          ...                        ...
#  6292  2022-08-15    US_NY_NYC                      107.0
#  6293  2022-08-16    US_NY_NYC                       98.0
#  6294  2022-08-17    US_NY_NYC                       75.0
#  6295  2022-08-18    US_NY_NYC                       41.0
#  6296  2022-08-19    US_NY_NYC                       23.0
#
#        cumulative_hospitalized_patients  current_hospitalized_patients  \
#  0                                  NaN                          101.0
#  1                                  NaN                           96.0
#  2                                  NaN                           62.0
#  3                                  NaN                           67.0
#  4                                  NaN                           69.0
#  ...                                ...                            ...
#  6292                          165162.0                            NaN
#  6293                          165260.0                            NaN
#  6294                          165335.0                            NaN
#  6295                          165376.0                            NaN
#  6296                          165399.0                            NaN
#
#        new_intensive_care_patients  cumulative_intensive_care_patients  \
#  0                             NaN                                 NaN
#  1                             NaN                                 NaN
#  2                             NaN                                 NaN
#  3                             NaN                                 NaN
#  4                             NaN                                 NaN
#  ...                           ...                                 ...
#  6292                          NaN                                 NaN
#  6293                          NaN                                 NaN
#  6294                          NaN                                 NaN
#  6295                          NaN                                 NaN
#  6296                          NaN                                 NaN
#
#        current_intensive_care_patients  new_ventilator_patients  \
#  0                                21.0                      NaN
#  1                                15.0                      NaN
#  2                                12.0                      NaN
#  3                                13.0                      NaN
#  4                                10.0                      NaN
#  ...                               ...                      ...
#  6292                              NaN                      NaN
#  6293                              NaN                      NaN
#  6294                              NaN                      NaN
#  6295                              NaN                      NaN
#  6296                              NaN                      NaN
#
#        cumulative_ventilator_patients  current_ventilator_patients
#  0                                NaN                          NaN
#  1                                NaN                          NaN
#  2                                NaN                          NaN
#  3                                NaN                          NaN
#  4                                NaN                          NaN
#  ...                              ...                          ...
#  6292                             NaN                          NaN
#  6293                             NaN                          NaN
#  6294                             NaN                          NaN
#  6295                             NaN                          NaN
#  6296                             NaN                          NaN
#
#  [6297 rows x 11 columns],
#  'index':      location_key                     place_id wikidata_id datacommons_id  \
#  0     DE_BB_12051  ChIJN8I30-XAqEcRhUxEEOyL_kg       Q3931            NaN
#  1     DE_BB_12052  ChIJX0qVWUJ0CEcROq1_4LUv1FA       Q3214            NaN
#  2     DE_BB_12053  ChIJb_u1AiqYB0cRwDteW0YgIQQ       Q4024            NaN
#  3     DE_BB_12054  ChIJt9Y6hM31qEcRm-yqC5j4ZcU       Q1711            NaN
#  4     DE_BB_12060  ChIJuRSkBF66qUcRCDglm8hflWE       Q6115            NaN
#  ...           ...                          ...         ...            ...
#  5116  US_WY_56037  ChIJEVZf4rRTWocRoqATF0f_rnA     Q484194    geoId/56037
#  5117  US_WY_56039  ChIJV3wGpVVrUlMR3m18oGf5rvk     Q488912    geoId/56039
#  5118  US_WY_56041  ChIJR4w4T5CnUYcRvTPRgMmXumM     Q483973    geoId/56041
#  5119  US_WY_56043  ChIJIXR5_L9BS1MRLvs8KUxeZC8     Q112846    geoId/56043
#  5120  US_WY_56045  ChIJd4Rqhed3YocR7ubT5-HgoJg     Q115413    geoId/56045
#
#       country_code              country_name subregion1_code subregion1_name  \
#  0              DE                   Germany              BB     Brandenburg
#  1              DE                   Germany              BB     Brandenburg
#  2              DE                   Germany              BB     Brandenburg
#  3              DE                   Germany              BB     Brandenburg
#  4              DE                   Germany              BB     Brandenburg
#  ...           ...                       ...             ...             ...
#  5116           US  United States of America              WY         Wyoming
#  5117           US  United States of America              WY         Wyoming
#  5118           US  United States of America              WY         Wyoming
#  5119           US  United States of America              WY         Wyoming
#  5120           US  United States of America              WY         Wyoming
#
#       subregion2_code           subregion2_name locality_code locality_name  \
#  0              12051  Brandenburg an der Havel           NaN           NaN
#  1              12052                   Cottbus           NaN           NaN
#  2              12053     Frankfurt an der Oder           NaN           NaN
#  3              12054                   Potsdam           NaN           NaN
#  4              12060                    Barnim           NaN           NaN
#  ...              ...                       ...           ...           ...
#  5116           56037         Sweetwater County           NaN           NaN
#  5117           56039              Teton County           NaN           NaN
#  5118           56041              Uinta County           NaN           NaN
#  5119           56043           Washakie County           NaN           NaN
#  5120           56045             Weston County           NaN           NaN
#
#       iso_3166_1_alpha_2 iso_3166_1_alpha_3  aggregation_level
#  0                    DE                DEU                  2
#  1                    DE                DEU                  2
#  2                    DE                DEU                  2
#  3                    DE                DEU                  2
#  4                    DE                DEU                  2
#  ...                 ...                ...                ...
#  5116                 US                USA                  2
#  5117                 US                USA                  2
#  5118                 US                USA                  2
#  5119                 US                USA                  2
#  5120                 US                USA                  2
#
#  [5121 rows x 15 columns],
#  'macrotable.csv':                       week location_key  new_confirmed  new_deceased  \
#  0    2019-12-30/2020-01-05           DE            1.0           0.0
#  1    2020-01-13/2020-01-19           DE            1.0           0.0
#  2    2020-01-20/2020-01-26           DE            2.0           0.0
#  3    2020-01-20/2020-01-26           US            0.0           0.0
#  4    2020-01-27/2020-02-02           DE            6.0           0.0
#  ..                     ...          ...            ...           ...
#  500  2022-08-08/2022-08-14           IT       154987.0           0.0
#  501  2022-08-08/2022-08-14           US       122778.0         502.0
#  502  2022-08-15/2022-08-21           IT       127160.0           0.0
#  503  2022-08-15/2022-08-21           US       107459.0         400.0
#  504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#       new_hospitalized_patients  new_persons_fully_vaccinated  life_expectancy  \
#  0                          NaN                           NaN              NaN
#  1                          NaN                           NaN              NaN
#  2                          NaN                           NaN              NaN
#  3                          NaN                           NaN    144407.097716
#  4                          NaN                           NaN              NaN
#  ..                         ...                           ...              ...
#  500                        NaN                           NaN              NaN
#  501                     1548.0                      240164.0    144407.097716
#  502                        NaN                           NaN              NaN
#  503                      669.0                      180458.0    144407.097716
#  504                        NaN                           NaN              NaN
#
#        population  population_male  population_female  population_age_00_09  \
#  0     82786787.0       40126479.0         41172726.0             7401202.0
#  1     82786787.0       40126479.0         41172726.0             7401202.0
#  2     82786787.0       40126479.0         41172726.0             7401202.0
#  3    341338766.0      167361582.0        172779253.0            42034674.0
#  4     82786787.0       40126479.0         41172726.0             7401202.0
#  ..           ...              ...                ...                   ...
#  500   55443101.0       26986652.0         28456449.0             4633566.0
#  501  341338766.0      167361582.0        172779253.0            42034674.0
#  502   55443101.0       26986652.0         28456449.0             4633566.0
#  503  341338766.0      167361582.0        172779253.0            42034674.0
#  504   55443101.0       26986652.0         28456449.0             4633566.0
#
#       population_age_10_19  population_age_20_29  population_age_30_39  \
#  0               7586334.0             9513883.0            10265460.0
#  1               7586334.0             9513883.0            10265460.0
#  2               7586334.0             9513883.0            10265460.0
#  3              43600405.0            47667343.0            45409648.0
#  4               7586334.0             9513883.0            10265460.0
#  ..                    ...                   ...                   ...
#  500             5231560.0             5623413.0             6471216.0
#  501            43600405.0            47667343.0            45409648.0
#  502             5231560.0             5623413.0             6471216.0
#  503            43600405.0            47667343.0            45409648.0
#  504             5231560.0             5623413.0             6471216.0
#
#       population_age_40_49  population_age_50_59  population_age_60_69  \
#  0              10205383.0            13258896.0            10159451.0
#  1              10205383.0            13258896.0            10159451.0
#  2              10205383.0            13258896.0            10159451.0
#  3              42444067.0            45231261.0            38309532.0
#  4              10205383.0            13258896.0            10159451.0
#  ..                    ...                   ...                   ...
#  500             8507701.0             8610615.0             6764526.0
#  501            42444067.0            45231261.0            38309532.0
#  502             8507701.0             8610615.0             6764526.0
#  503            42444067.0            45231261.0            38309532.0
#  504             8507701.0             8610615.0             6764526.0
#
#       population_age_70_79  population_age_80_and_older  \
#  0               7543815.0                    5313340.0
#  1               7543815.0                    5313340.0
#  2               7543815.0                    5313340.0
#  3              22458802.0                   12982024.0
#  4               7543815.0                    5313340.0
#  ..                    ...                          ...
#  500             5533564.0                    4066940.0
#  501            22458802.0                   12982024.0
#  502             5533564.0                    4066940.0
#  503            22458802.0                   12982024.0
#  504             5533564.0                    4066940.0
#
#                   country_name
#  0                     Germany
#  1                     Germany
#  2                     Germany
#  3    United States of America
#  4                     Germany
#  ..                        ...
#  500                     Italy
#  501  United States of America
#  502                     Italy
#  503  United States of America
#  504                     Italy
#
#  [505 rows x 20 columns],
#  'vaccinations':                date location_key  new_persons_vaccinated  \
#  0        2021-04-26  US_AK_02013                     NaN
#  1        2021-04-27  US_AK_02013                     NaN
#  2        2021-04-28  US_AK_02013                     NaN
#  3        2021-04-29  US_AK_02013                     NaN
#  4        2021-04-30  US_AK_02013                     NaN
#  ...             ...          ...                     ...
#  1562409  2022-08-19  US_WY_56045                     NaN
#  1562410  2022-08-20  US_WY_56045                     NaN
#  1562411  2022-08-21  US_WY_56045                     NaN
#  1562412  2022-08-22  US_WY_56045                     NaN
#  1562413  2022-08-23  US_WY_56045                     NaN
#
#           cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
#  0                                  NaN                           NaN
#  1                                  NaN                           0.0
#  2                                  NaN                           1.0
#  3                                  NaN                           0.0
#  4                                  NaN                           1.0
#  ...                                ...                           ...
#  1562409                            NaN                           0.0
#  1562410                            NaN                           0.0
#  1562411                            NaN                           0.0
#  1562412                            NaN                           0.0
#  1562413                            NaN                           0.0
#
#           cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
#  0                                      918.0                             NaN
#  1                                      918.0                             NaN
#  2                                      919.0                             NaN
#  3                                      919.0                             NaN
#  4                                      920.0                             NaN
#  ...                                      ...                             ...
#  1562409                               2671.0                             NaN
#  1562410                               2671.0                             NaN
#  1562411                               2671.0                             NaN
#  1562412                               2671.0                             NaN
#  1562413                               2671.0                             NaN
#
#           cumulative_vaccine_doses_administered  new_persons_vaccinated_pfizer  \
#  0                                          NaN                            NaN
#  1                                          NaN                            NaN
#  2                                          NaN                            NaN
#  3                                          NaN                            NaN
#  4                                          NaN                            NaN
#  ...                                        ...                            ...
#  1562409                                    NaN                            NaN
#  1562410                                    NaN                            NaN
#  1562411                                    NaN                            NaN
#  1562412                                    NaN                            NaN
#  1562413                                    NaN                            NaN
#
#           cumulative_persons_vaccinated_pfizer  ...  \
#  0                                         NaN  ...
#  1                                         NaN  ...
#  2                                         NaN  ...
#  3                                         NaN  ...
#  4                                         NaN  ...
#  ...                                       ...  ...
#  1562409                                   NaN  ...
#  1562410                                   NaN  ...
#  1562411                                   NaN  ...
#  1562412                                   NaN  ...
#  1562413                                   NaN  ...
#
#           new_persons_fully_vaccinated_janssen  \
#  0                                         NaN
#  1                                         NaN
#  2                                         NaN
#  3                                         NaN
#  4                                         NaN
#  ...                                       ...
#  1562409                                   NaN
#  1562410                                   NaN
#  1562411                                   NaN
#  1562412                                   NaN
#  1562413                                   NaN
#
#           cumulative_persons_fully_vaccinated_janssen  \
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN
#  ...                                              ...
#  1562409                                          NaN
#  1562410                                          NaN
#  1562411                                          NaN
#  1562412                                          NaN
#  1562413                                          NaN
#
#           new_vaccine_doses_administered_janssen  \
#  0                                           NaN
#  1                                           NaN
#  2                                           NaN
#  3                                           NaN
#  4                                           NaN
#  ...                                         ...
#  1562409                                     NaN
#  1562410                                     NaN
#  1562411                                     NaN
#  1562412                                     NaN
#  1562413                                     NaN
#
#           cumulative_vaccine_doses_administered_janssen  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ...                                                ...
#  1562409                                            NaN
#  1562410                                            NaN
#  1562411                                            NaN
#  1562412                                            NaN
#  1562413                                            NaN
#
#           new_persons_vaccinated_sinovac  total_persons_vaccinated_sinovac  \
#  0                                   NaN                               NaN
#  1                                   NaN                               NaN
#  2                                   NaN                               NaN
#  3                                   NaN                               NaN
#  4                                   NaN                               NaN
#  ...                                 ...                               ...
#  1562409                             NaN                               NaN
#  1562410                             NaN                               NaN
#  1562411                             NaN                               NaN
#  1562412                             NaN                               NaN
#  1562413                             NaN                               NaN
#
#           new_persons_fully_vaccinated_sinovac  \
#  0                                         NaN
#  1                                         NaN
#  2                                         NaN
#  3                                         NaN
#  4                                         NaN
#  ...                                       ...
#  1562409                                   NaN
#  1562410                                   NaN
#  1562411                                   NaN
#  1562412                                   NaN
#  1562413                                   NaN
#
#           total_persons_fully_vaccinated_sinovac  \
#  0                                           NaN
#  1                                           NaN
#  2                                           NaN
#  3                                           NaN
#  4                                           NaN
#  ...                                         ...
#  1562409                                     NaN
#  1562410                                     NaN
#  1562411                                     NaN
#  1562412                                     NaN
#  1562413                                     NaN
#
#           new_vaccine_doses_administered_sinovac  \
#  0                                           NaN
#  1                                           NaN
#  2                                           NaN
#  3                                           NaN
#  4                                           NaN
#  ...                                         ...
#  1562409                                     NaN
#  1562410                                     NaN
#  1562411                                     NaN
#  1562412                                     NaN
#  1562413                                     NaN
#
#           total_vaccine_doses_administered_sinovac
#  0                                             NaN
#  1                                             NaN
#  2                                             NaN
#  3                                             NaN
#  4                                             NaN
#  ...                                           ...
#  1562409                                       NaN
#  1562410                                       NaN
#  1562411                                       NaN
#  1562412                                       NaN
#  1562413                                       NaN
#
#  [1562414 rows x 32 columns]}

# %% [markdown]
# ##

# %% [markdown]
# ### **Part II: Transformation process**
#
# #### **_Extracting columns for our tables_**
# For this part, a previous scan of each of the data sets was performed in order to decide which columns we would keep. For this, we performed a missing values ratio and a relevance study. We decided to drop columns that were either repetitive or had more than 50% of values missing.
#
# For this part, we assume that all the tables are being uploaded with all of the existing columns.

# %%
    #First, we do our column dictionary
column_dict={
    'demographics': ['location_key','population','population_male','population_female','population_age_00_09','population_age_10_19','population_age_20_29','population_age_30_39','population_age_40_49','population_age_50_59','population_age_60_69','population_age_70_79','population_age_80_and_older'],
    'epidemiology':['date','location_key','new_confirmed','new_deceased'],
    'health':['location_key','life_expectancy'],
    'hospitalizations':['date','location_key','new_hospitalized_patients'],
    'index':['location_key','country_name'],
    'vaccinations':['date','location_key','new_persons_fully_vaccinated']
}

# %%
def assign_columns(tables:dict, column_dict:dict):

    # We go through each table in our dictionaries and reassign the columns we want for that table.
    for key, value in tables.items():
        if key in column_dict:
            tables[key]=value[column_dict[key]]

    return tables

# %% [markdown]
# Using our function on our data frame.

# %%
data=assign_columns(data, column_dict)
data
# Out:
# {'demographics':      location_key  population  population_male  population_female  \
#  0     DE_BB_12051     72124.0          35617.0            36507.0
#  1     DE_BB_12052    100219.0          49201.0            51018.0
#  2     DE_BB_12053     57873.0          28023.0            29850.0
#  3     DE_BB_12054    178089.0          86179.0            91910.0
#  4     DE_BB_12060    182760.0          90615.0            92145.0
#  ...           ...         ...              ...                ...
#  5092  US_WY_56037     43464.0          22438.0            21026.0
#  5093  US_WY_56039     23384.0          12133.0            11251.0
#  5094  US_WY_56041     20431.0          10339.0            10092.0
#  5095  US_WY_56043      8010.0           4055.0             3955.0
#  5096  US_WY_56045      6968.0           3660.0             3308.0
#
#        population_age_00_09  population_age_10_19  population_age_20_29  \
#  0                   6029.0                5183.0                6646.0
#  1                   8542.0                7657.0               10979.0
#  2                   4652.0                4702.0                5977.0
#  3                  18893.0               15636.0               21671.0
#  4                  16693.0               15671.0               12966.0
#  ...                    ...                   ...                   ...
#  5092                6334.0                6333.0                5488.0
#  5093                2461.0                2245.0                3184.0
#  5094                3282.0                3182.0                2179.0
#  5095                 913.0                1162.0                 705.0
#  5096                 777.0                 789.0                 728.0
#
#        population_age_30_39  population_age_40_49  population_age_50_59  \
#  0                   9776.0                7690.0               11604.0
#  1                  13671.0               10652.0               15833.0
#  2                   7066.0                6405.0                9325.0
#  3                  28980.0               23226.0               24768.0
#  4                  23038.0               22973.0               33665.0
#  ...                    ...                   ...                   ...
#  5092                6734.0                5219.0                5534.0
#  5093                4184.0                3404.0                2968.0
#  5094                2755.0                2349.0                2567.0
#  5095                 938.0                 902.0                1101.0
#  5096                 932.0                 741.0                1009.0
#
#        population_age_60_69  population_age_70_79  population_age_80_and_older
#  0                  10152.0                8681.0                       6363.0
#  1                  14258.0               10758.0                       7869.0
#  2                   9042.0                6049.0                       4655.0
#  3                  18998.0               14762.0                      11155.0
#  4                  27041.0               18553.0                      12160.0
#  ...                    ...                   ...                          ...
#  5092                4815.0                2063.0                        944.0
#  5093                2855.0                1435.0                        648.0
#  5094                2496.0                1116.0                        505.0
#  5095                1106.0                 752.0                        431.0
#  5096                1068.0                 541.0                        383.0
#
#  [5097 rows x 13 columns],
#  'epidemiology':                date location_key  new_confirmed  new_deceased
#  0        2020-03-15  DE_BB_12051            2.0           0.0
#  1        2020-03-17  DE_BB_12051            1.0           0.0
#  2        2020-03-19  DE_BB_12051            2.0           0.0
#  3        2020-03-20  DE_BB_12051            1.0           0.0
#  4        2020-03-22  DE_BB_12051            2.0           0.0
#  ...             ...          ...            ...           ...
#  3161028  2022-05-09  US_WY_56045            0.0           0.0
#  3161029  2022-05-10  US_WY_56045           -1.0           0.0
#  3161030  2022-05-11  US_WY_56045            0.0           0.0
#  3161031  2022-05-12  US_WY_56045            0.0           0.0
#  3161032  2022-05-13  US_WY_56045            0.0           0.0
#
#  [3161033 rows x 4 columns],
#  'health':      location_key  life_expectancy
#  0     US_AK_02013        86.900000
#  1     US_AK_02016        77.750000
#  2     US_AK_02020        78.034694
#  3     US_AK_02050        78.733333
#  4     US_AK_02060        79.900000
#  ...           ...              ...
#  3017  US_WY_56037        79.177778
#  3018  US_WY_56039        81.950000
#  3019  US_WY_56041        77.700000
#  3020  US_WY_56043        80.600000
#  3021  US_WY_56045        78.800000
#
#  [3022 rows x 2 columns],
#  'hospitalizations':             date location_key  new_hospitalized_patients
#  0     2020-03-23    US_CA_SFO                        NaN
#  1     2020-03-24    US_CA_SFO                        NaN
#  2     2020-03-25    US_CA_SFO                        NaN
#  3     2020-03-26    US_CA_SFO                        NaN
#  4     2020-03-27    US_CA_SFO                        NaN
#  ...          ...          ...                        ...
#  6292  2022-08-15    US_NY_NYC                      107.0
#  6293  2022-08-16    US_NY_NYC                       98.0
#  6294  2022-08-17    US_NY_NYC                       75.0
#  6295  2022-08-18    US_NY_NYC                       41.0
#  6296  2022-08-19    US_NY_NYC                       23.0
#
#  [6297 rows x 3 columns],
#  'index':      location_key              country_name
#  0     DE_BB_12051                   Germany
#  1     DE_BB_12052                   Germany
#  2     DE_BB_12053                   Germany
#  3     DE_BB_12054                   Germany
#  4     DE_BB_12060                   Germany
#  ...           ...                       ...
#  5116  US_WY_56037  United States of America
#  5117  US_WY_56039  United States of America
#  5118  US_WY_56041  United States of America
#  5119  US_WY_56043  United States of America
#  5120  US_WY_56045  United States of America
#
#  [5121 rows x 2 columns],
#  'macrotable.csv':                       week location_key  new_confirmed  new_deceased  \
#  0    2019-12-30/2020-01-05           DE            1.0           0.0
#  1    2020-01-13/2020-01-19           DE            1.0           0.0
#  2    2020-01-20/2020-01-26           DE            2.0           0.0
#  3    2020-01-20/2020-01-26           US            0.0           0.0
#  4    2020-01-27/2020-02-02           DE            6.0           0.0
#  ..                     ...          ...            ...           ...
#  500  2022-08-08/2022-08-14           IT       154987.0           0.0
#  501  2022-08-08/2022-08-14           US       122778.0         502.0
#  502  2022-08-15/2022-08-21           IT       127160.0           0.0
#  503  2022-08-15/2022-08-21           US       107459.0         400.0
#  504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#       new_hospitalized_patients  new_persons_fully_vaccinated  life_expectancy  \
#  0                          NaN                           NaN              NaN
#  1                          NaN                           NaN              NaN
#  2                          NaN                           NaN              NaN
#  3                          NaN                           NaN    144407.097716
#  4                          NaN                           NaN              NaN
#  ..                         ...                           ...              ...
#  500                        NaN                           NaN              NaN
#  501                     1548.0                      240164.0    144407.097716
#  502                        NaN                           NaN              NaN
#  503                      669.0                      180458.0    144407.097716
#  504                        NaN                           NaN              NaN
#
#        population  population_male  population_female  population_age_00_09  \
#  0     82786787.0       40126479.0         41172726.0             7401202.0
#  1     82786787.0       40126479.0         41172726.0             7401202.0
#  2     82786787.0       40126479.0         41172726.0             7401202.0
#  3    341338766.0      167361582.0        172779253.0            42034674.0
#  4     82786787.0       40126479.0         41172726.0             7401202.0
#  ..           ...              ...                ...                   ...
#  500   55443101.0       26986652.0         28456449.0             4633566.0
#  501  341338766.0      167361582.0        172779253.0            42034674.0
#  502   55443101.0       26986652.0         28456449.0             4633566.0
#  503  341338766.0      167361582.0        172779253.0            42034674.0
#  504   55443101.0       26986652.0         28456449.0             4633566.0
#
#       population_age_10_19  population_age_20_29  population_age_30_39  \
#  0               7586334.0             9513883.0            10265460.0
#  1               7586334.0             9513883.0            10265460.0
#  2               7586334.0             9513883.0            10265460.0
#  3              43600405.0            47667343.0            45409648.0
#  4               7586334.0             9513883.0            10265460.0
#  ..                    ...                   ...                   ...
#  500             5231560.0             5623413.0             6471216.0
#  501            43600405.0            47667343.0            45409648.0
#  502             5231560.0             5623413.0             6471216.0
#  503            43600405.0            47667343.0            45409648.0
#  504             5231560.0             5623413.0             6471216.0
#
#       population_age_40_49  population_age_50_59  population_age_60_69  \
#  0              10205383.0            13258896.0            10159451.0
#  1              10205383.0            13258896.0            10159451.0
#  2              10205383.0            13258896.0            10159451.0
#  3              42444067.0            45231261.0            38309532.0
#  4              10205383.0            13258896.0            10159451.0
#  ..                    ...                   ...                   ...
#  500             8507701.0             8610615.0             6764526.0
#  501            42444067.0            45231261.0            38309532.0
#  502             8507701.0             8610615.0             6764526.0
#  503            42444067.0            45231261.0            38309532.0
#  504             8507701.0             8610615.0             6764526.0
#
#       population_age_70_79  population_age_80_and_older  \
#  0               7543815.0                    5313340.0
#  1               7543815.0                    5313340.0
#  2               7543815.0                    5313340.0
#  3              22458802.0                   12982024.0
#  4               7543815.0                    5313340.0
#  ..                    ...                          ...
#  500             5533564.0                    4066940.0
#  501            22458802.0                   12982024.0
#  502             5533564.0                    4066940.0
#  503            22458802.0                   12982024.0
#  504             5533564.0                    4066940.0
#
#                   country_name
#  0                     Germany
#  1                     Germany
#  2                     Germany
#  3    United States of America
#  4                     Germany
#  ..                        ...
#  500                     Italy
#  501  United States of America
#  502                     Italy
#  503  United States of America
#  504                     Italy
#
#  [505 rows x 20 columns],
#  'vaccinations':                date location_key  new_persons_fully_vaccinated
#  0        2021-04-26  US_AK_02013                           NaN
#  1        2021-04-27  US_AK_02013                           0.0
#  2        2021-04-28  US_AK_02013                           1.0
#  3        2021-04-29  US_AK_02013                           0.0
#  4        2021-04-30  US_AK_02013                           1.0
#  ...             ...          ...                           ...
#  1562409  2022-08-19  US_WY_56045                           0.0
#  1562410  2022-08-20  US_WY_56045                           0.0
#  1562411  2022-08-21  US_WY_56045                           0.0
#  1562412  2022-08-22  US_WY_56045                           0.0
#  1562413  2022-08-23  US_WY_56045                           0.0
#
#  [1562414 rows x 3 columns]}

# %% [markdown]
# Since we will only be joining our data by country, we will transform the location_key column to keep only the first two characters, which represent the country. This will also help us avoid issues when aggreagating our information.

# %%
def loc_key_transformation (tables:dict):
    location='location_key'
    for key,value in tables.items():
        if location in value.columns:
            value[location]=value[location].str[:2]
    tables[key]=value
    return tables

# %%
data=loc_key_transformation(data)

# %% [markdown]
# #### **_Dropping duplicates and empty rows function_**
# For this part, we are dropping any duplicates or completely empty rows for all the tables

# %%
def dropping_dup_empty (tables: dict):
    for key,value in tables.items():
        value=value.drop_duplicates()
        value=value.dropna(how='all')
        tables[key]=value
    return tables

# %% [markdown]
# Using our function on our data set

# %%
data=dropping_dup_empty(data)
data
# Out:
# {'demographics':      location_key  population  population_male  population_female  \
#  0              DE     72124.0          35617.0            36507.0
#  1              DE    100219.0          49201.0            51018.0
#  2              DE     57873.0          28023.0            29850.0
#  3              DE    178089.0          86179.0            91910.0
#  4              DE    182760.0          90615.0            92145.0
#  ...           ...         ...              ...                ...
#  5092           US     43464.0          22438.0            21026.0
#  5093           US     23384.0          12133.0            11251.0
#  5094           US     20431.0          10339.0            10092.0
#  5095           US      8010.0           4055.0             3955.0
#  5096           US      6968.0           3660.0             3308.0
#
#        population_age_00_09  population_age_10_19  population_age_20_29  \
#  0                   6029.0                5183.0                6646.0
#  1                   8542.0                7657.0               10979.0
#  2                   4652.0                4702.0                5977.0
#  3                  18893.0               15636.0               21671.0
#  4                  16693.0               15671.0               12966.0
#  ...                    ...                   ...                   ...
#  5092                6334.0                6333.0                5488.0
#  5093                2461.0                2245.0                3184.0
#  5094                3282.0                3182.0                2179.0
#  5095                 913.0                1162.0                 705.0
#  5096                 777.0                 789.0                 728.0
#
#        population_age_30_39  population_age_40_49  population_age_50_59  \
#  0                   9776.0                7690.0               11604.0
#  1                  13671.0               10652.0               15833.0
#  2                   7066.0                6405.0                9325.0
#  3                  28980.0               23226.0               24768.0
#  4                  23038.0               22973.0               33665.0
#  ...                    ...                   ...                   ...
#  5092                6734.0                5219.0                5534.0
#  5093                4184.0                3404.0                2968.0
#  5094                2755.0                2349.0                2567.0
#  5095                 938.0                 902.0                1101.0
#  5096                 932.0                 741.0                1009.0
#
#        population_age_60_69  population_age_70_79  population_age_80_and_older
#  0                  10152.0                8681.0                       6363.0
#  1                  14258.0               10758.0                       7869.0
#  2                   9042.0                6049.0                       4655.0
#  3                  18998.0               14762.0                      11155.0
#  4                  27041.0               18553.0                      12160.0
#  ...                    ...                   ...                          ...
#  5092                4815.0                2063.0                        944.0
#  5093                2855.0                1435.0                        648.0
#  5094                2496.0                1116.0                        505.0
#  5095                1106.0                 752.0                        431.0
#  5096                1068.0                 541.0                        383.0
#
#  [4891 rows x 13 columns],
#  'epidemiology':                date location_key  new_confirmed  new_deceased
#  0        2020-03-15           DE            2.0           0.0
#  1        2020-03-17           DE            1.0           0.0
#  2        2020-03-19           DE            2.0           0.0
#  3        2020-03-20           DE            1.0           0.0
#  4        2020-03-22           DE            2.0           0.0
#  ...             ...          ...            ...           ...
#  3160153  2021-12-02           US           -8.0           0.0
#  3160164  2021-12-13           US          -10.0           0.0
#  3160186  2022-01-04           US            6.0           2.0
#  3160568  2021-02-03           US            1.0          -1.0
#  3160854  2021-11-16           US            5.0           3.0
#
#  [525064 rows x 4 columns],
#  'health':      location_key  life_expectancy
#  0              US        86.900000
#  1              US        77.750000
#  2              US        78.034694
#  3              US        78.733333
#  4              US        79.900000
#  ...           ...              ...
#  3008           US        83.900000
#  3009           US        80.441176
#  3011           US        79.529412
#  3016           US        81.950000
#  3017           US        79.177778
#
#  [1852 rows x 2 columns],
#  'hospitalizations':             date location_key  new_hospitalized_patients
#  0     2020-03-23           US                        NaN
#  1     2020-03-24           US                        NaN
#  2     2020-03-25           US                        NaN
#  3     2020-03-26           US                        NaN
#  4     2020-03-27           US                        NaN
#  ...          ...          ...                        ...
#  6292  2022-08-15           US                      107.0
#  6293  2022-08-16           US                       98.0
#  6294  2022-08-17           US                       75.0
#  6295  2022-08-18           US                       41.0
#  6296  2022-08-19           US                       23.0
#
#  [6023 rows x 3 columns],
#  'index':      location_key              country_name
#  0              DE                   Germany
#  412            ES                     Spain
#  1790           IT                     Italy
#  1893           US  United States of America,
#  'macrotable.csv':                       week location_key  new_confirmed  new_deceased  \
#  0    2019-12-30/2020-01-05           DE            1.0           0.0
#  1    2020-01-13/2020-01-19           DE            1.0           0.0
#  2    2020-01-20/2020-01-26           DE            2.0           0.0
#  3    2020-01-20/2020-01-26           US            0.0           0.0
#  4    2020-01-27/2020-02-02           DE            6.0           0.0
#  ..                     ...          ...            ...           ...
#  500  2022-08-08/2022-08-14           IT       154987.0           0.0
#  501  2022-08-08/2022-08-14           US       122778.0         502.0
#  502  2022-08-15/2022-08-21           IT       127160.0           0.0
#  503  2022-08-15/2022-08-21           US       107459.0         400.0
#  504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#       new_hospitalized_patients  new_persons_fully_vaccinated  life_expectancy  \
#  0                          NaN                           NaN              NaN
#  1                          NaN                           NaN              NaN
#  2                          NaN                           NaN              NaN
#  3                          NaN                           NaN    144407.097716
#  4                          NaN                           NaN              NaN
#  ..                         ...                           ...              ...
#  500                        NaN                           NaN              NaN
#  501                     1548.0                      240164.0    144407.097716
#  502                        NaN                           NaN              NaN
#  503                      669.0                      180458.0    144407.097716
#  504                        NaN                           NaN              NaN
#
#        population  population_male  population_female  population_age_00_09  \
#  0     82786787.0       40126479.0         41172726.0             7401202.0
#  1     82786787.0       40126479.0         41172726.0             7401202.0
#  2     82786787.0       40126479.0         41172726.0             7401202.0
#  3    341338766.0      167361582.0        172779253.0            42034674.0
#  4     82786787.0       40126479.0         41172726.0             7401202.0
#  ..           ...              ...                ...                   ...
#  500   55443101.0       26986652.0         28456449.0             4633566.0
#  501  341338766.0      167361582.0        172779253.0            42034674.0
#  502   55443101.0       26986652.0         28456449.0             4633566.0
#  503  341338766.0      167361582.0        172779253.0            42034674.0
#  504   55443101.0       26986652.0         28456449.0             4633566.0
#
#       population_age_10_19  population_age_20_29  population_age_30_39  \
#  0               7586334.0             9513883.0            10265460.0
#  1               7586334.0             9513883.0            10265460.0
#  2               7586334.0             9513883.0            10265460.0
#  3              43600405.0            47667343.0            45409648.0
#  4               7586334.0             9513883.0            10265460.0
#  ..                    ...                   ...                   ...
#  500             5231560.0             5623413.0             6471216.0
#  501            43600405.0            47667343.0            45409648.0
#  502             5231560.0             5623413.0             6471216.0
#  503            43600405.0            47667343.0            45409648.0
#  504             5231560.0             5623413.0             6471216.0
#
#       population_age_40_49  population_age_50_59  population_age_60_69  \
#  0              10205383.0            13258896.0            10159451.0
#  1              10205383.0            13258896.0            10159451.0
#  2              10205383.0            13258896.0            10159451.0
#  3              42444067.0            45231261.0            38309532.0
#  4              10205383.0            13258896.0            10159451.0
#  ..                    ...                   ...                   ...
#  500             8507701.0             8610615.0             6764526.0
#  501            42444067.0            45231261.0            38309532.0
#  502             8507701.0             8610615.0             6764526.0
#  503            42444067.0            45231261.0            38309532.0
#  504             8507701.0             8610615.0             6764526.0
#
#       population_age_70_79  population_age_80_and_older  \
#  0               7543815.0                    5313340.0
#  1               7543815.0                    5313340.0
#  2               7543815.0                    5313340.0
#  3              22458802.0                   12982024.0
#  4               7543815.0                    5313340.0
#  ..                    ...                          ...
#  500             5533564.0                    4066940.0
#  501            22458802.0                   12982024.0
#  502             5533564.0                    4066940.0
#  503            22458802.0                   12982024.0
#  504             5533564.0                    4066940.0
#
#                   country_name
#  0                     Germany
#  1                     Germany
#  2                     Germany
#  3    United States of America
#  4                     Germany
#  ..                        ...
#  500                     Italy
#  501  United States of America
#  502                     Italy
#  503  United States of America
#  504                     Italy
#
#  [505 rows x 20 columns],
#  'vaccinations':                date location_key  new_persons_fully_vaccinated
#  0        2021-04-26           US                           NaN
#  1        2021-04-27           US                           0.0
#  2        2021-04-28           US                           1.0
#  3        2021-04-29           US                           0.0
#  4        2021-04-30           US                           1.0
#  ...             ...          ...                           ...
#  1560214  2021-12-07           US                         125.0
#  1560489  2021-05-11           US                         372.0
#  1560699  2021-12-07           US                         256.0
#  1560853  2022-05-10           US                         -16.0
#  1561228  2022-01-20           US                         411.0
#
#  [145241 rows x 3 columns]}

# %% [markdown]
# #### **_Data Cleaning_**
# For this part, we are filling null values and dropping rows that do not make sense.
#
# - **'location_key'**: If it's empty, we will not be able to infer where the data comes from, so we will drop the row.
# - **'date'** : If it's empty, we will not be able to infer where the data comes from, so we will drop the row.
# - **'population**: If this is empty we will be replacing with the median of the same location.
# - **'new_confirmed':** If this is empty we will be replacing with 0 because we assume the NaN is due to no cases being reported.
# - **'new_deceased':** If this is empty we will be replacing with 0 because we assume the NaN is due to no cases being reported.
# - **'life_expectancy':** If this is empty we will be replacing with the median of the same location.
# - **'new_hospitalized_patients':** If this is empty we will be replacing with 0 because we assume the NaN is due to no cases being reported.
# - **'new_persons_fully_vaccinated':** If this is empty we will be replacing with 0 because we assume the NaN is due to no cases being reported.

# %% [markdown]
# For this, we will have most functions separated, depending on their purpose, and we will then join them in a master function.

# %% [markdown]
# ### **_Clean on empty location_key or dates_**
# We drop rows that do not have a location_key or date because it would be very hard to identify where the information comes from.

# %%
def drop_empty(tables:dict):

    for key,value in tables.items():
        #Check if the table has the column location key before applying the drop function to avoid errors.
        if 'location_key' in value.columns: 
            value=value.dropna(subset=['location_key'])
        #Check if the table has the column date before applying the drop function to avoid errors.
        if 'date' in value.columns:
            value=value.dropna(subset=['date'])
        #Reassigning the corrected table in our tables dictionary
        tables[key]=value    
        
    return tables

# %% [markdown]
# ### **_Filter dates and countries_**

# %%
def filter(tables:dict,start:str, end:str, countries:list):
#We filter countries
    if 'index' in tables and countries:
        tables['index']=tables['index'][tables['index'].country_name.isin(countries)]
    for key,value in tables.items():
        if 'date' in value.columns: #Check if there is a date column in our table
            value=value[(value['date']>=start)&(value['date']<=end)]
        tables[key]=value
    return tables

# %% [markdown]
# ### **_Fill Population and Life Expectancy Data_**
# We will fill this information with the median of each location, this will be to take care of possible outliers.

# %%
def fill_median(tables:dict):
    #List of columns we will be changing
    change_column=['population','population_male','population_female','population_age_00_09',
                 'population_age_10_19','population_age_20_29','population_age_30_39','population_age_40_49',
                 'population_age_50_59','population_age_60_69','population_age_70_79','population_age_80_and_older',
                 'life_expectancy']
    
    #We will do a for loop to go through each column inside our table and apply the changes were there need to be
    
    for key,value in tables.items(): #Accesing the tables in our dictionary
        for col in change_column: #Accesing the list of columns
            if col in value.columns: #Checking if the column is in our table
                med=value.groupby('location_key')[col].median() #We create a table with the values grouped with their median by location
                value[col]=value[col].fillna(value['location_key'].map(med)) #Filling with the median of our column with the corresponding value.
                #We use the map function which will locate the location key in our table and match it in our med table (with the grouped values),
                #then it will return the median value
        
        tables[key]=value
        
    return tables

# %% [markdown]
# ### **_Fill New Cases_**
# We will fill this information with 0 because we assume the NaN is due to no cases being reported.

# %%
def fill_zero(tables:dict):
    #List of columns we will be changing
    change_column=['new_confirmed','new_deceased','new_hospitalized_patients','new_persons_fully_vaccinated']
    
    #We will do a for loop to go through each column inside our table and apply the changes were there need to be
    
    for key,value in tables.items(): #Accesing the tables in our dictionary
        for col in change_column: #Accesing the list of columns
            if col in value.columns: #Checking if the column is in our table
                value[col]=value[col].fillna(0) #Filling with 0.
        
        tables[key]=value
        
    return tables

# %% [markdown]
# ### **_Week Column Creation_**
# Now, we will create a column with the weeks where the dates correspond, and then we will drop the 'date' columns

# %% [markdown]
# First, we will transform all date columns into dates, since they are objects right now

# %%
def date_transformation(tables:dict):
    dt='date' #Assign name to a variable for simplicity
    for key,value in tables.items(): #For loop to go through our tables
        if dt in value.columns: #Checking tables that have a column 'date'
            value[dt]=pd.to_datetime(value[dt]) #Transforming the column into datetime
    tables[key]=value #Assigning the new table values to their corresponding key
    return tables

# %% [markdown]
# Now, we will add a week column to each of the tables and drop the date column

# %%
def week_dates(dt):
    st_date=(dt-pd.Timedelta(days=dt.weekday())).date() #First, we calculate the starting date of the week to which this date belongs to.
    end_date=(dt+pd.Timedelta(days=6-dt.weekday())).date() #Then, we calculate the ending date of the week to which this date belongs to.
    return f"{st_date}/{end_date}" #Format result

# %%
def week_column(tables:dict):
    for key,value in tables.items(): #For loop to go through our tables

        if 'date' in value.columns: #Checking tables that have a column 'date'
            
            value["week"] = value['date'].apply(week_dates) #Appy previous function to add column week with values

            value = value.drop(columns=['date']) #Drop date column
        tables[key]=value  #Assign new table to the key
    return tables

# %% [markdown]
# ### **_Turning all of the functions into a master function_**

# %%
def cleaning_data(tables:dict):
    tables=drop_empty(tables)
    tables=fill_median(tables)
    tables=fill_zero(tables)
    tables=date_transformation(tables)
    tables=week_column(tables)
    return tables

# %% [markdown]
# Using our functions in our data set

# %%
data=cleaning_data(data)
data
# Out:
# {'demographics':      location_key  population  population_male  population_female  \
#  0              DE     72124.0          35617.0            36507.0
#  1              DE    100219.0          49201.0            51018.0
#  2              DE     57873.0          28023.0            29850.0
#  3              DE    178089.0          86179.0            91910.0
#  4              DE    182760.0          90615.0            92145.0
#  ...           ...         ...              ...                ...
#  5092           US     43464.0          22438.0            21026.0
#  5093           US     23384.0          12133.0            11251.0
#  5094           US     20431.0          10339.0            10092.0
#  5095           US      8010.0           4055.0             3955.0
#  5096           US      6968.0           3660.0             3308.0
#
#        population_age_00_09  population_age_10_19  population_age_20_29  \
#  0                   6029.0                5183.0                6646.0
#  1                   8542.0                7657.0               10979.0
#  2                   4652.0                4702.0                5977.0
#  3                  18893.0               15636.0               21671.0
#  4                  16693.0               15671.0               12966.0
#  ...                    ...                   ...                   ...
#  5092                6334.0                6333.0                5488.0
#  5093                2461.0                2245.0                3184.0
#  5094                3282.0                3182.0                2179.0
#  5095                 913.0                1162.0                 705.0
#  5096                 777.0                 789.0                 728.0
#
#        population_age_30_39  population_age_40_49  population_age_50_59  \
#  0                   9776.0                7690.0               11604.0
#  1                  13671.0               10652.0               15833.0
#  2                   7066.0                6405.0                9325.0
#  3                  28980.0               23226.0               24768.0
#  4                  23038.0               22973.0               33665.0
#  ...                    ...                   ...                   ...
#  5092                6734.0                5219.0                5534.0
#  5093                4184.0                3404.0                2968.0
#  5094                2755.0                2349.0                2567.0
#  5095                 938.0                 902.0                1101.0
#  5096                 932.0                 741.0                1009.0
#
#        population_age_60_69  population_age_70_79  population_age_80_and_older
#  0                  10152.0                8681.0                       6363.0
#  1                  14258.0               10758.0                       7869.0
#  2                   9042.0                6049.0                       4655.0
#  3                  18998.0               14762.0                      11155.0
#  4                  27041.0               18553.0                      12160.0
#  ...                    ...                   ...                          ...
#  5092                4815.0                2063.0                        944.0
#  5093                2855.0                1435.0                        648.0
#  5094                2496.0                1116.0                        505.0
#  5095                1106.0                 752.0                        431.0
#  5096                1068.0                 541.0                        383.0
#
#  [4891 rows x 13 columns],
#  'epidemiology':         location_key  new_confirmed  new_deceased                   week
#  0                 DE            2.0           0.0  2020-03-09/2020-03-15
#  1                 DE            1.0           0.0  2020-03-16/2020-03-22
#  2                 DE            2.0           0.0  2020-03-16/2020-03-22
#  3                 DE            1.0           0.0  2020-03-16/2020-03-22
#  4                 DE            2.0           0.0  2020-03-16/2020-03-22
#  ...              ...            ...           ...                    ...
#  3160153           US           -8.0           0.0  2021-11-29/2021-12-05
#  3160164           US          -10.0           0.0  2021-12-13/2021-12-19
#  3160186           US            6.0           2.0  2022-01-03/2022-01-09
#  3160568           US            1.0          -1.0  2021-02-01/2021-02-07
#  3160854           US            5.0           3.0  2021-11-15/2021-11-21
#
#  [525064 rows x 4 columns],
#  'health':      location_key  life_expectancy
#  0              US        86.900000
#  1              US        77.750000
#  2              US        78.034694
#  3              US        78.733333
#  4              US        79.900000
#  ...           ...              ...
#  3008           US        83.900000
#  3009           US        80.441176
#  3011           US        79.529412
#  3016           US        81.950000
#  3017           US        79.177778
#
#  [1852 rows x 2 columns],
#  'hospitalizations':      location_key  new_hospitalized_patients                   week
#  0              US                        0.0  2020-03-23/2020-03-29
#  1              US                        0.0  2020-03-23/2020-03-29
#  2              US                        0.0  2020-03-23/2020-03-29
#  3              US                        0.0  2020-03-23/2020-03-29
#  4              US                        0.0  2020-03-23/2020-03-29
#  ...           ...                        ...                    ...
#  6292           US                      107.0  2022-08-15/2022-08-21
#  6293           US                       98.0  2022-08-15/2022-08-21
#  6294           US                       75.0  2022-08-15/2022-08-21
#  6295           US                       41.0  2022-08-15/2022-08-21
#  6296           US                       23.0  2022-08-15/2022-08-21
#
#  [6023 rows x 3 columns],
#  'index':      location_key              country_name
#  0              DE                   Germany
#  412            ES                     Spain
#  1790           IT                     Italy
#  1893           US  United States of America,
#  'macrotable.csv':                       week location_key  new_confirmed  new_deceased  \
#  0    2019-12-30/2020-01-05           DE            1.0           0.0
#  1    2020-01-13/2020-01-19           DE            1.0           0.0
#  2    2020-01-20/2020-01-26           DE            2.0           0.0
#  3    2020-01-20/2020-01-26           US            0.0           0.0
#  4    2020-01-27/2020-02-02           DE            6.0           0.0
#  ..                     ...          ...            ...           ...
#  500  2022-08-08/2022-08-14           IT       154987.0           0.0
#  501  2022-08-08/2022-08-14           US       122778.0         502.0
#  502  2022-08-15/2022-08-21           IT       127160.0           0.0
#  503  2022-08-15/2022-08-21           US       107459.0         400.0
#  504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#       new_hospitalized_patients  new_persons_fully_vaccinated  life_expectancy  \
#  0                          0.0                           0.0              NaN
#  1                          0.0                           0.0              NaN
#  2                          0.0                           0.0              NaN
#  3                          0.0                           0.0    144407.097716
#  4                          0.0                           0.0              NaN
#  ..                         ...                           ...              ...
#  500                        0.0                           0.0              NaN
#  501                     1548.0                      240164.0    144407.097716
#  502                        0.0                           0.0              NaN
#  503                      669.0                      180458.0    144407.097716
#  504                        0.0                           0.0              NaN
#
#        population  population_male  population_female  population_age_00_09  \
#  0     82786787.0       40126479.0         41172726.0             7401202.0
#  1     82786787.0       40126479.0         41172726.0             7401202.0
#  2     82786787.0       40126479.0         41172726.0             7401202.0
#  3    341338766.0      167361582.0        172779253.0            42034674.0
#  4     82786787.0       40126479.0         41172726.0             7401202.0
#  ..           ...              ...                ...                   ...
#  500   55443101.0       26986652.0         28456449.0             4633566.0
#  501  341338766.0      167361582.0        172779253.0            42034674.0
#  502   55443101.0       26986652.0         28456449.0             4633566.0
#  503  341338766.0      167361582.0        172779253.0            42034674.0
#  504   55443101.0       26986652.0         28456449.0             4633566.0
#
#       population_age_10_19  population_age_20_29  population_age_30_39  \
#  0               7586334.0             9513883.0            10265460.0
#  1               7586334.0             9513883.0            10265460.0
#  2               7586334.0             9513883.0            10265460.0
#  3              43600405.0            47667343.0            45409648.0
#  4               7586334.0             9513883.0            10265460.0
#  ..                    ...                   ...                   ...
#  500             5231560.0             5623413.0             6471216.0
#  501            43600405.0            47667343.0            45409648.0
#  502             5231560.0             5623413.0             6471216.0
#  503            43600405.0            47667343.0            45409648.0
#  504             5231560.0             5623413.0             6471216.0
#
#       population_age_40_49  population_age_50_59  population_age_60_69  \
#  0              10205383.0            13258896.0            10159451.0
#  1              10205383.0            13258896.0            10159451.0
#  2              10205383.0            13258896.0            10159451.0
#  3              42444067.0            45231261.0            38309532.0
#  4              10205383.0            13258896.0            10159451.0
#  ..                    ...                   ...                   ...
#  500             8507701.0             8610615.0             6764526.0
#  501            42444067.0            45231261.0            38309532.0
#  502             8507701.0             8610615.0             6764526.0
#  503            42444067.0            45231261.0            38309532.0
#  504             8507701.0             8610615.0             6764526.0
#
#       population_age_70_79  population_age_80_and_older  \
#  0               7543815.0                    5313340.0
#  1               7543815.0                    5313340.0
#  2               7543815.0                    5313340.0
#  3              22458802.0                   12982024.0
#  4               7543815.0                    5313340.0
#  ..                    ...                          ...
#  500             5533564.0                    4066940.0
#  501            22458802.0                   12982024.0
#  502             5533564.0                    4066940.0
#  503            22458802.0                   12982024.0
#  504             5533564.0                    4066940.0
#
#                   country_name
#  0                     Germany
#  1                     Germany
#  2                     Germany
#  3    United States of America
#  4                     Germany
#  ..                        ...
#  500                     Italy
#  501  United States of America
#  502                     Italy
#  503  United States of America
#  504                     Italy
#
#  [505 rows x 20 columns],
#  'vaccinations':         location_key  new_persons_fully_vaccinated                   week
#  0                 US                           0.0  2021-04-26/2021-05-02
#  1                 US                           0.0  2021-04-26/2021-05-02
#  2                 US                           1.0  2021-04-26/2021-05-02
#  3                 US                           0.0  2021-04-26/2021-05-02
#  4                 US                           1.0  2021-04-26/2021-05-02
#  ...              ...                           ...                    ...
#  1560214           US                         125.0  2021-12-06/2021-12-12
#  1560489           US                         372.0  2021-05-10/2021-05-16
#  1560699           US                         256.0  2021-12-06/2021-12-12
#  1560853           US                         -16.0  2022-05-09/2022-05-15
#  1561228           US                         411.0  2022-01-17/2022-01-23
#
#  [145241 rows x 3 columns]}

# %% [markdown]
# ### **_Aggregations_**
#
# First, we will be doing our aggregations in our tables

# %%
def aggregations (tables:dict):

    for key,value in tables.items():
        if 'week' in value.columns and 'location_key' in value.columns:
            value=value.groupby(by=['week','location_key'], as_index=False).sum()
        elif 'location_key' in value.columns and 'week' not in value.columns:
            if key=='health':
                value=value.groupby(by='location_key', as_index=False).mean()
            else:
                value=value.groupby(by='location_key', as_index=False).sum()
        tables[key]=value
    return tables

# %%
data['index']
# Out:
#   location_key              country_name
# 0           DE                   Germany
# 1           ES                     Spain
# 2           IT                     Italy
# 3           US  United States of America

# %%
data=aggregations(data)
data
# Out:
# {'demographics':   location_key   population  population_male  population_female  \
#  0           DE   82786787.0       40126479.0         41172726.0
#  1           ES   19357122.0        8224314.0          8300422.0
#  2           IT   55443101.0       26986652.0         28456449.0
#  3           US  341338766.0      167361582.0        172779253.0
#
#     population_age_00_09  population_age_10_19  population_age_20_29  \
#  0             7401202.0             7586334.0             9513883.0
#  1             1513858.0             1713301.0             1703871.0
#  2             4633566.0             5231560.0             5623413.0
#  3            42034674.0            43600405.0            47667343.0
#
#     population_age_30_39  population_age_40_49  population_age_50_59  \
#  0            10265460.0            10205383.0            13258896.0
#  1             2111146.0             2739366.0             2474428.0
#  2             6471216.0             8507701.0             8610615.0
#  3            45409648.0            42444067.0            45231261.0
#
#     population_age_60_69  population_age_70_79  population_age_80_and_older
#  0            10159451.0             7543815.0                    5313340.0
#  1             1899658.0             1399847.0                     992477.0
#  2             6764526.0             5533564.0                    4066940.0
#  3            38309532.0            22458802.0                   12982024.0  ,
#  'epidemiology':                       week location_key  new_confirmed  new_deceased
#  0    2019-12-30/2020-01-05           DE            1.0           0.0
#  1    2020-01-13/2020-01-19           DE            1.0           0.0
#  2    2020-01-20/2020-01-26           DE            2.0           0.0
#  3    2020-01-20/2020-01-26           US            0.0           0.0
#  4    2020-01-27/2020-02-02           DE            6.0           0.0
#  ..                     ...          ...            ...           ...
#  500  2022-08-08/2022-08-14           IT       154987.0           0.0
#  501  2022-08-08/2022-08-14           US       122778.0         502.0
#  502  2022-08-15/2022-08-21           IT       127160.0           0.0
#  503  2022-08-15/2022-08-21           US       107459.0         400.0
#  504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#  [505 rows x 4 columns],
#  'health':   location_key  life_expectancy
#  0           US        77.973595,
#  'hospitalizations':                       week location_key  new_hospitalized_patients
#  0    2020-02-24/2020-03-01           US                        2.0
#  1    2020-03-02/2020-03-08           US                      111.0
#  2    2020-03-09/2020-03-15           US                     1619.0
#  3    2020-03-16/2020-03-22           US                     8220.0
#  4    2020-03-23/2020-03-29           US                    19846.0
#  ..                     ...          ...                        ...
#  125  2022-07-18/2022-07-24           US                     2377.0
#  126  2022-07-25/2022-07-31           US                     1892.0
#  127  2022-08-01/2022-08-07           US                     1810.0
#  128  2022-08-08/2022-08-14           US                     1548.0
#  129  2022-08-15/2022-08-21           US                      669.0
#
#  [130 rows x 3 columns],
#  'index':   location_key              country_name
#  0           DE                   Germany
#  1           ES                     Spain
#  2           IT                     Italy
#  3           US  United States of America,
#  'macrotable.csv':                       week location_key  new_confirmed  new_deceased  \
#  0    2019-12-30/2020-01-05           DE            1.0           0.0
#  1    2020-01-13/2020-01-19           DE            1.0           0.0
#  2    2020-01-20/2020-01-26           DE            2.0           0.0
#  3    2020-01-20/2020-01-26           US            0.0           0.0
#  4    2020-01-27/2020-02-02           DE            6.0           0.0
#  ..                     ...          ...            ...           ...
#  500  2022-08-08/2022-08-14           IT       154987.0           0.0
#  501  2022-08-08/2022-08-14           US       122778.0         502.0
#  502  2022-08-15/2022-08-21           IT       127160.0           0.0
#  503  2022-08-15/2022-08-21           US       107459.0         400.0
#  504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#       new_hospitalized_patients  new_persons_fully_vaccinated  life_expectancy  \
#  0                          0.0                           0.0         0.000000
#  1                          0.0                           0.0         0.000000
#  2                          0.0                           0.0         0.000000
#  3                          0.0                           0.0    144407.097716
#  4                          0.0                           0.0         0.000000
#  ..                         ...                           ...              ...
#  500                        0.0                           0.0         0.000000
#  501                     1548.0                      240164.0    144407.097716
#  502                        0.0                           0.0         0.000000
#  503                      669.0                      180458.0    144407.097716
#  504                        0.0                           0.0         0.000000
#
#        population  population_male  population_female  population_age_00_09  \
#  0     82786787.0       40126479.0         41172726.0             7401202.0
#  1     82786787.0       40126479.0         41172726.0             7401202.0
#  2     82786787.0       40126479.0         41172726.0             7401202.0
#  3    341338766.0      167361582.0        172779253.0            42034674.0
#  4     82786787.0       40126479.0         41172726.0             7401202.0
#  ..           ...              ...                ...                   ...
#  500   55443101.0       26986652.0         28456449.0             4633566.0
#  501  341338766.0      167361582.0        172779253.0            42034674.0
#  502   55443101.0       26986652.0         28456449.0             4633566.0
#  503  341338766.0      167361582.0        172779253.0            42034674.0
#  504   55443101.0       26986652.0         28456449.0             4633566.0
#
#       population_age_10_19  population_age_20_29  population_age_30_39  \
#  0               7586334.0             9513883.0            10265460.0
#  1               7586334.0             9513883.0            10265460.0
#  2               7586334.0             9513883.0            10265460.0
#  3              43600405.0            47667343.0            45409648.0
#  4               7586334.0             9513883.0            10265460.0
#  ..                    ...                   ...                   ...
#  500             5231560.0             5623413.0             6471216.0
#  501            43600405.0            47667343.0            45409648.0
#  502             5231560.0             5623413.0             6471216.0
#  503            43600405.0            47667343.0            45409648.0
#  504             5231560.0             5623413.0             6471216.0
#
#       population_age_40_49  population_age_50_59  population_age_60_69  \
#  0              10205383.0            13258896.0            10159451.0
#  1              10205383.0            13258896.0            10159451.0
#  2              10205383.0            13258896.0            10159451.0
#  3              42444067.0            45231261.0            38309532.0
#  4              10205383.0            13258896.0            10159451.0
#  ..                    ...                   ...                   ...
#  500             8507701.0             8610615.0             6764526.0
#  501            42444067.0            45231261.0            38309532.0
#  502             8507701.0             8610615.0             6764526.0
#  503            42444067.0            45231261.0            38309532.0
#  504             8507701.0             8610615.0             6764526.0
#
#       population_age_70_79  population_age_80_and_older  \
#  0               7543815.0                    5313340.0
#  1               7543815.0                    5313340.0
#  2               7543815.0                    5313340.0
#  3              22458802.0                   12982024.0
#  4               7543815.0                    5313340.0
#  ..                    ...                          ...
#  500             5533564.0                    4066940.0
#  501            22458802.0                   12982024.0
#  502             5533564.0                    4066940.0
#  503            22458802.0                   12982024.0
#  504             5533564.0                    4066940.0
#
#                   country_name
#  0                     Germany
#  1                     Germany
#  2                     Germany
#  3    United States of America
#  4                     Germany
#  ..                        ...
#  500                     Italy
#  501  United States of America
#  502                     Italy
#  503  United States of America
#  504                     Italy
#
#  [505 rows x 20 columns],
#  'vaccinations':                      week location_key  new_persons_fully_vaccinated
#  0   2021-04-26/2021-05-02           US                     5869047.0
#  1   2021-05-03/2021-05-09           US                     8655807.0
#  2   2021-05-10/2021-05-16           US                     7216140.0
#  3   2021-05-17/2021-05-23           US                     5351596.0
#  4   2021-05-24/2021-05-30           US                     3866025.0
#  ..                    ...          ...                           ...
#  65  2022-07-25/2022-07-31           US                      219890.0
#  66  2022-08-01/2022-08-07           US                     -215177.0
#  67  2022-08-08/2022-08-14           US                      240164.0
#  68  2022-08-15/2022-08-21           US                      180458.0
#  69  2022-08-22/2022-08-28           US                           0.0
#
#  [70 rows x 3 columns]}

# %% [markdown]
# ### **_Joins_**
# Now, we will be joining out information taking into account our results

# %%
def joins(tables:dict):
    #First we join epidemiology table with hospitalization table with a left outer join to not lose values
    t1=pd.merge(tables['epidemiology'],tables['hospitalizations'],how="left", on=['week','location_key'])
    #Then we join the resulting table with vaccinations table with a left outer join to not lose values
    t2=pd.merge(t1,tables['vaccinations'],how="left",on=['week','location_key'])
    #Then we join the resulting table with health table with a left outer join to not lose values
    t3=pd.merge(t2,tables['health'],how="left")
    #Then we join our info tables demographics and index with an inner join
    t4=pd.merge(tables['demographics'],tables['index'],how="inner")
    #Then we get our final table with an inner join of t3 and t4
    final_table=pd.merge(t3,t4,how="inner")
    return final_table

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Documents\\MBD\\Courses\\Python for Data Analysis\\PDAI\\Group 4'

# %%
table=joins(data)
table
# Out:
#                       week location_key  new_confirmed  new_deceased  \
# 0    2019-12-30/2020-01-05           DE            1.0           0.0
# 1    2020-01-13/2020-01-19           DE            1.0           0.0
# 2    2020-01-20/2020-01-26           DE            2.0           0.0
# 3    2020-01-20/2020-01-26           US            0.0           0.0
# 4    2020-01-27/2020-02-02           DE            6.0           0.0
# ..                     ...          ...            ...           ...
# 500  2022-08-08/2022-08-14           IT       154987.0           0.0
# 501  2022-08-08/2022-08-14           US       122778.0         502.0
# 502  2022-08-15/2022-08-21           IT       127160.0           0.0
# 503  2022-08-15/2022-08-21           US       107459.0         400.0
# 504  2022-08-22/2022-08-28           IT         8013.0           0.0
#
#      new_hospitalized_patients  new_persons_fully_vaccinated  life_expectancy  \
# 0                          NaN                           NaN              NaN
# 1                          NaN                           NaN              NaN
# 2                          NaN                           NaN              NaN
# 3                          NaN                           NaN        77.973595
# 4                          NaN                           NaN              NaN
# ..                         ...                           ...              ...
# 500                        NaN                           NaN              NaN
# 501                     1548.0                      240164.0        77.973595
# 502                        NaN                           NaN              NaN
# 503                      669.0                      180458.0        77.973595
# 504                        NaN                           NaN              NaN
#
#       population  population_male  population_female  population_age_00_09  \
# 0     82786787.0       40126479.0         41172726.0             7401202.0
# 1     82786787.0       40126479.0         41172726.0             7401202.0
# 2     82786787.0       40126479.0         41172726.0             7401202.0
# 3    341338766.0      167361582.0        172779253.0            42034674.0
# 4     82786787.0       40126479.0         41172726.0             7401202.0
# ..           ...              ...                ...                   ...
# 500   55443101.0       26986652.0         28456449.0             4633566.0
# 501  341338766.0      167361582.0        172779253.0            42034674.0
# 502   55443101.0       26986652.0         28456449.0             4633566.0
# 503  341338766.0      167361582.0        172779253.0            42034674.0
# 504   55443101.0       26986652.0         28456449.0             4633566.0
#
#      population_age_10_19  population_age_20_29  population_age_30_39  \
# 0               7586334.0             9513883.0            10265460.0
# 1               7586334.0             9513883.0            10265460.0
# 2               7586334.0             9513883.0            10265460.0
# 3              43600405.0            47667343.0            45409648.0
# 4               7586334.0             9513883.0            10265460.0
# ..                    ...                   ...                   ...
# 500             5231560.0             5623413.0             6471216.0
# 501            43600405.0            47667343.0            45409648.0
# 502             5231560.0             5623413.0             6471216.0
# 503            43600405.0            47667343.0            45409648.0
# 504             5231560.0             5623413.0             6471216.0
#
#      population_age_40_49  population_age_50_59  population_age_60_69  \
# 0              10205383.0            13258896.0            10159451.0
# 1              10205383.0            13258896.0            10159451.0
# 2              10205383.0            13258896.0            10159451.0
# 3              42444067.0            45231261.0            38309532.0
# 4              10205383.0            13258896.0            10159451.0
# ..                    ...                   ...                   ...
# 500             8507701.0             8610615.0             6764526.0
# 501            42444067.0            45231261.0            38309532.0
# 502             8507701.0             8610615.0             6764526.0
# 503            42444067.0            45231261.0            38309532.0
# 504             8507701.0             8610615.0             6764526.0
#
#      population_age_70_79  population_age_80_and_older  \
# 0               7543815.0                    5313340.0
# 1               7543815.0                    5313340.0
# 2               7543815.0                    5313340.0
# 3              22458802.0                   12982024.0
# 4               7543815.0                    5313340.0
# ..                    ...                          ...
# 500             5533564.0                    4066940.0
# 501            22458802.0                   12982024.0
# 502             5533564.0                    4066940.0
# 503            22458802.0                   12982024.0
# 504             5533564.0                    4066940.0
#
#                  country_name
# 0                     Germany
# 1                     Germany
# 2                     Germany
# 3    United States of America
# 4                     Germany
# ..                        ...
# 500                     Italy
# 501  United States of America
# 502                     Italy
# 503  United States of America
# 504                     Italy
#
# [505 rows x 20 columns]

# %%
table.describe()
# Out:
#        new_confirmed  new_deceased  new_hospitalized_patients  \
# count   5.050000e+02    505.000000                 130.000000
# mean    2.019994e+05   1885.332673                2519.561538
# std     4.774958e+05   3911.875903                3756.430061
# min    -4.120000e+02      0.000000                   2.000000
# 25%     9.289000e+03      0.000000                 591.000000
# 50%     4.986500e+04     28.000000                1276.000000
# 75%     1.963480e+05   1460.000000                2683.500000
# max     5.153090e+06  22378.000000               23486.000000
#
#        new_persons_fully_vaccinated  life_expectancy    population  \
# count                  6.900000e+01     1.350000e+02  5.050000e+02
# mean                   1.669640e+06     7.797359e+01  1.287343e+08
# std                    2.493827e+06     1.283740e-13  1.304101e+08
# min                   -2.151770e+05     7.797359e+01  1.935712e+07
# 25%                    2.592650e+05     7.797359e+01  1.935712e+07
# 50%                    9.000410e+05     7.797359e+01  5.544310e+07
# 75%                    1.796788e+06     7.797359e+01  3.413388e+08
# max                    1.634720e+07     7.797359e+01  3.413388e+08
#
#        population_male  population_female  population_age_00_09  \
# count     5.050000e+02       5.050000e+02          5.050000e+02
# mean      6.264518e+07       6.472400e+07          1.444948e+07
# std       6.427700e+07       6.633297e+07          1.680195e+07
# min       8.224314e+06       8.300422e+06          1.513858e+06
# 25%       8.224314e+06       8.300422e+06          1.513858e+06
# 50%       2.698665e+07       2.845645e+07          4.633566e+06
# 75%       1.673616e+08       1.727793e+08          4.203467e+07
# max       1.673616e+08       1.727793e+08          4.203467e+07
#
#        population_age_10_19  population_age_20_29  population_age_30_39  \
# count          5.050000e+02          5.050000e+02          5.050000e+02
# mean           1.511441e+07          1.672454e+07          1.660936e+07
# std            1.734449e+07          1.890091e+07          1.763911e+07
# min            1.713301e+06          1.703871e+06          2.111146e+06
# 25%            1.713301e+06          1.703871e+06          2.111146e+06
# 50%            5.231560e+06          5.623413e+06          6.471216e+06
# 75%            4.360040e+07          4.766734e+07          4.540965e+07
# max            4.360040e+07          4.766734e+07          4.540965e+07
#
#        population_age_40_49  population_age_50_59  population_age_60_69  \
# count          5.050000e+02          5.050000e+02          5.050000e+02
# mean           1.649088e+07          1.786668e+07          1.471049e+07
# std            1.592836e+07          1.696149e+07          1.455427e+07
# min            2.739366e+06          2.474428e+06          1.899658e+06
# 25%            2.739366e+06          2.474428e+06          1.899658e+06
# 50%            8.507701e+06          8.610615e+06          6.764526e+06
# 75%            4.244407e+07          4.523126e+07          3.830953e+07
# max            4.244407e+07          4.523126e+07          3.830953e+07
#
#        population_age_70_79  population_age_80_and_older
# count          5.050000e+02                 5.050000e+02
# mean           9.452236e+06                 5.944872e+06
# std            8.159326e+06                 4.527477e+06
# min            1.399847e+06                 9.924770e+05
# 25%            1.399847e+06                 9.924770e+05
# 50%            5.533564e+06                 4.066940e+06
# 75%            2.245880e+07                 1.298202e+07
# max            2.245880e+07                 1.298202e+07

# %%
macrotable=pd.read_csv("C:/Users/HP/Documents/MBD/Courses/Python for Data Analysis/PDAI/Group Assignment/data/macrotable/macrotable_c")
macrotable.describe()
# Out:
#        new_confirmed  new_deceased  new_deceased_confirmed_ratio  \
# count   5.040000e+02    504.000000                    504.000000
# mean    2.465923e+05   2286.992063                      0.004206
# std     5.406483e+05   4633.637370                      0.014912
# min    -6.700000e+01      0.000000                      0.000000
# 25%     1.632925e+04      0.000000                      0.000000
# 50%     7.102250e+04     31.000000                      0.000000
# 75%     2.507910e+05   1934.500000                      0.000715
# max     5.656738e+06  25873.000000                      0.250000
#
#          population  population_age_00_09  population_age_10_19  \
# count  5.040000e+02          5.040000e+02          5.040000e+02
# mean   1.293220e+08          1.464182e+07          1.534543e+07
# std    1.301284e+08          1.678827e+07          1.730140e+07
# min    2.109846e+07          1.915634e+06          2.266531e+06
# 25%    2.109846e+07          1.915634e+06          2.266531e+06
# 50%    5.544310e+07          4.633566e+06          5.231560e+06
# 75%    3.413388e+08          4.218540e+07          4.375102e+07
# max    3.413388e+08          4.218540e+07          4.375102e+07
#
#        population_age_20_29  population_age_30_39  population_age_40_49  \
# count          5.040000e+02          5.040000e+02          5.040000e+02
# mean           1.700617e+07          1.693672e+07          1.684963e+07
# std            1.885862e+07          1.754758e+07          1.577286e+07
# min            2.337994e+06          2.942982e+06          3.758505e+06
# 25%            2.337994e+06          2.942982e+06          3.758505e+06
# 50%            5.623413e+06          6.471216e+06          8.507701e+06
# 75%            4.787080e+07          4.560237e+07          4.260209e+07
# max            4.787080e+07          4.560237e+07          4.260209e+07
#
#        population_age_50_59  population_age_60_69  population_age_70_79  \
# count          5.040000e+02          5.040000e+02          5.040000e+02
# mean           1.819974e+07          1.492381e+07          9.584126e+06
# std            1.682029e+07          1.447775e+07          8.099128e+06
# min            3.351295e+06          2.417174e+06          1.717090e+06
# 25%            3.351295e+06          2.417174e+06          1.717090e+06
# 50%            8.610615e+06          6.764526e+06          5.533564e+06
# 75%            4.537366e+07          3.840401e+07          2.250539e+07
# max            4.537366e+07          3.840401e+07          2.250539e+07
#
#        population_age_80_and_older  life_expectancy  \
# count                 5.040000e+02     1.350000e+02
# mean                  6.019731e+06     7.787200e+01
# std                   4.497196e+06     1.569016e-13
# min                   1.152301e+06     7.787200e+01
# 25%                   1.152301e+06     7.787200e+01
# 50%                   4.066940e+06     7.787200e+01
# 75%                   1.301387e+07     7.787200e+01
# max                   1.301387e+07     7.787200e+01
#
#        new_hospitalized_patients  new_persons_fully_vaccinated
# count                 135.000000                  1.350000e+02
# mean                 2544.600000                  1.021703e+06
# std                  3682.569298                  2.132879e+06
# min                     4.000000                 -1.682610e+05
# 25%                   616.000000                  0.000000e+00
# 50%                  1336.000000                  4.375900e+04
# 75%                  2591.300000                  1.259466e+06
# max                 23486.000000                  1.676596e+07

# %%
macrotable
# Out:
#                       week              country_name  new_confirmed  \
# 0    2019-12-30/2020-01-05                   Germany            1.0
# 1    2020-01-13/2020-01-19                   Germany            1.0
# 2    2020-01-20/2020-01-26                   Germany            2.0
# 3    2020-01-20/2020-01-26  United States of America            0.0
# 4    2020-01-27/2020-02-02                   Germany           10.0
# ..                     ...                       ...            ...
# 499  2022-08-01/2022-08-07  United States of America       157249.0
# 500  2022-08-08/2022-08-14                     Italy       169974.0
# 501  2022-08-08/2022-08-14  United States of America       126631.0
# 502  2022-08-15/2022-08-21                     Italy       137729.0
# 503  2022-08-15/2022-08-21  United States of America       110333.0
#
#      new_deceased  new_deceased_confirmed_ratio   population  \
# 0             0.0                      0.000000   82786787.0
# 1             0.0                      0.000000   82786787.0
# 2             0.0                      0.000000   82786787.0
# 3             0.0                      0.000000  341338766.0
# 4             0.0                      0.000000   82786787.0
# ..            ...                           ...          ...
# 499         489.0                      0.000922  341338766.0
# 500           0.0                      0.000000   55443101.0
# 501         502.0                      0.001763  341338766.0
# 502           0.0                      0.000000   55443101.0
# 503         400.0                      0.000879  341338766.0
#
#      population_age_00_09  population_age_10_19  population_age_20_29  \
# 0            7.539514e+06          7.725134e+06          9.713905e+06
# 1            7.539514e+06          7.725134e+06          9.713905e+06
# 2            7.539514e+06          7.725134e+06          9.713905e+06
# 3            4.218540e+07          4.375102e+07          4.787080e+07
# 4            7.539514e+06          7.725134e+06          9.713905e+06
# ..                    ...                   ...                   ...
# 499          4.218540e+07          4.375102e+07          4.787080e+07
# 500          4.633566e+06          5.231560e+06          5.623413e+06
# 501          4.218540e+07          4.375102e+07          4.787080e+07
# 502          4.633566e+06          5.231560e+06          5.623413e+06
# 503          4.218540e+07          4.375102e+07          4.787080e+07
#
#      population_age_30_39  population_age_40_49  population_age_50_59  \
# 0            1.046693e+07          1.039496e+07          1.350341e+07
# 1            1.046693e+07          1.039496e+07          1.350341e+07
# 2            1.046693e+07          1.039496e+07          1.350341e+07
# 3            4.560237e+07          4.260209e+07          4.537366e+07
# 4            1.046693e+07          1.039496e+07          1.350341e+07
# ..                    ...                   ...                   ...
# 499          4.560237e+07          4.260209e+07          4.537366e+07
# 500          6.471216e+06          8.507701e+06          8.610615e+06
# 501          4.560237e+07          4.260209e+07          4.537366e+07
# 502          6.471216e+06          8.507701e+06          8.610615e+06
# 503          4.560237e+07          4.260209e+07          4.537366e+07
#
#      population_age_60_69  population_age_70_79  population_age_80_and_older  \
# 0            1.034477e+07          7.684878e+06                 5.413285e+06
# 1            1.034477e+07          7.684878e+06                 5.413285e+06
# 2            1.034477e+07          7.684878e+06                 5.413285e+06
# 3            3.840401e+07          2.250539e+07                 1.301387e+07
# 4            1.034477e+07          7.684878e+06                 5.413285e+06
# ..                    ...                   ...                          ...
# 499          3.840401e+07          2.250539e+07                 1.301387e+07
# 500          6.764526e+06          5.533564e+06                 4.066940e+06
# 501          3.840401e+07          2.250539e+07                 1.301387e+07
# 502          6.764526e+06          5.533564e+06                 4.066940e+06
# 503          3.840401e+07          2.250539e+07                 1.301387e+07
#
#      life_expectancy  new_hospitalized_patients  new_persons_fully_vaccinated
# 0                NaN                        NaN                           NaN
# 1                NaN                        NaN                           NaN
# 2                NaN                        NaN                           NaN
# 3          77.871999                     2544.6                           0.0
# 4                NaN                        NaN                           NaN
# ..               ...                        ...                           ...
# 499        77.871999                     1810.0                     -168261.0
# 500              NaN                        NaN                           NaN
# 501        77.871999                     1598.0                      324776.0
# 502              NaN                        NaN                           NaN
# 503        77.871999                      688.0                      243539.0
#
# [504 rows x 18 columns]

# %% [markdown]
# ## **File Exportation**

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Documents\\MBD\\Courses\\Python for Data Analysis\\PDAI\\Group 4'

# %%
def export(tables:pd.DataFrame,directory:str):
    current=os.getcwd()
    if os.path.exists(directory):
        path1=os.path.join(directory,"macrotable.csv")
        tables.to_csv(path1,index=False)
    else:
        path2=os.path.join(current,"macrotable.csv")
        tables.to_csv(path2, index=False)

# %%
export(table,"data/")
